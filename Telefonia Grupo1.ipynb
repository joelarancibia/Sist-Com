# %%
# !pip install twilio==5.7.0
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/22/35/7a689c70470cb5f7d4d73bae07c4775efe0d23a9e5573714bf4090854979/twilio-5.7.0.tar.gz
# ...
#   Using cached https://files.pythonhosted.org/packages/75/d0/f213003c9deec99fb4f46e54580b93a3b121c487d9d6d888fc12267eb2a2/httplib2-0.12.1.tar.gz
# ...
#   Running setup.py bdist_wheel for twilio: started
#   Running setup.py bdist_wheel for twilio: finished with status 'done'
#   Stored in directory: C:\Users\sandr\AppData\Local\pip\Cache\wheels\b5\99\1d\3626f085ed601453fe4e969340b13d1de5d62c668771c543f2
#   Running setup.py bdist_wheel for httplib2: started
#   Running setup.py bdist_wheel for httplib2: finished with status 'done'
#   Stored in directory: C:\Users\sandr\AppData\Local\pip\Cache\wheels\98\82\0d\cfb126a5e40d487157e43fdb3332937713dde36b4d0e1e754d
# Successfully built twilio httplib2
# ...

# %%
from twilio.rest import TwilioRestClient

# %%
    
from twilio.rest import TwilioRestClient

# %%
TWILIO_PHONE_NUMBER = "+13344215257"

# %%
DIAL_NUMBERS = ["+59170742991","+59177908443","+59176411240"]

# %%
TWIML_INSTRUCTIONS_URL = \
  "https://vidaenred.org/llamada-Sist_Com.xml"

# %%
client = TwilioRestClient("AC26dd3b1cb2f04b5a0603c328778d760a", "2f4d3abf547bd9b190adac1553d39ea2")

def dial_numbers(numbers_lists):
    for number in numbers_lists:
        print("Dialing"+ number)
        client.calls.create(to=number, from_=TWILIO_PHONE_NUMBER, url=TWIML_INSTRUCTIONS_URL, method="GET")

# %%
if __name__ == "__main__":
    dial_numbers(DIAL_NUMBERS)
# Out:
# Dialing+59170742991

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1 Para crear el automata que al contestar te responde con un mensaje que ya esta definido en el link

# %% [markdown]
# 2. Para definir el token y el SID con el numero del cliente

# %% [markdown]
# 3. recibe la lista numeros a llamar y realiza la llamada
