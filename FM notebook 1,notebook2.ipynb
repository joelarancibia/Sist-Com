# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from scipy.io.wavfile import write

# %%
mps=44100 #muestras por segundo
frec_portadora = 440 #hz
frec_moduladora = 0.25 #hz
duracion = 10 #hz

# %%
muestras = np.arange(mps*duracion)

# %%
portadora = np.sin(2*np.pi*frec_portadora* muestras/mps)
portadora *=0.3
portadora_ints = np.int16(portadora*32767)

# %%
t1 = np.arange(0,10,0.01)# para senial portadora

# %%
plt.plot(t1[:1000],portadora[:1000])

# %%
#senial moduladora

# %%
moduladora = np.sin(2*np.pi*frec_moduladora*muestras/mps)

# %%
graf_portadora=plt.plot(moduladora)
plt.xlabel("[t]s")
plt.ylabel("[amplitud]")
# Out:
# Text(0, 0.5, '[amplitud]')

# %%
modulante = portadora*np.sin(2*np.pi*frec_portadora*(muestras*mps)+(portadora/moduladora)*np.cos(2*np.pi*frec_moduladora*(muestras/mps)))
# Out:
# C:\Users\joelo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in true_divide
#   """Entry point for launching an IPython kernel.
# C:\Users\joelo\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sin
#   """Entry point for launching an IPython kernel.

# %%
t3=np.arange(0.0,44100,0.1)# para la resultante
t3=np.radians(t3)

# %%
plt.plot(t3[:1000],modulante[:1000])

# %%
write('señal-resultante-Fm.wav', mps, portadora_ints)

# %% [markdown]
# # notebook1

# %% [markdown]
# 1.-para realizar la modulacion fm los parametros basicos no cambian lo que llega a cambiar es la formula para generar la señal resultante ya que para sacar la señal fm(modulante) la portadora se multiplica por el seno de pi porla frecuencia portadora y  por las muestras luego se suma las muestras con la señal portadora sobre la moduladora y despues se multiplica por el coseno de 2 pi por la frecuencia moduladora y por las muestras sobre las muestras por segundo

# %% [markdown]
# 2.- es una señal que contiene la informacion para transmitir y que se la inserta en la señal portadora para el proceso de modulacion

# %% [markdown]
# 3.-el indice de modulacion sirve para describir la profundidad de la señal modulada en terminos de amplitud y frecuencia

# %% [markdown]
# # notebook2

# %% [markdown]
# 1.a.- la amplitud de la señal portadora es mas pequeña que la modulada podria decirse que la señal moduladora era mucho mas pequeña que la portadora y solo se llego hasta esa amplitud

# %% [markdown]
# 1.b.-la amplitud de la señal portadora es grande mientras que la frecuencia en la señal modulada son muy cortas y la frecuencia esta muy unida

# %% [markdown]
# 2.- si la frecuencia moduladora llega ser mayor a la portadora el grafico de la modulante o audio no serviria y no se oiria nada
